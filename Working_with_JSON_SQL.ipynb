# %%
# JSON -> JAVA SCRIPT ON NOTATION
# SQL -> STRUCTURED QUERY LANGUAGE

# %%
import pandas as pd

# %%
# working with JSON
# loading dataset

pd.read_json('train.json')
# Out:
#           id      cuisine                                        ingredients
# 0      10259        greek  [romaine lettuce, black olives, grape tomatoes...
# 1      25693  southern_us  [plain flour, ground pepper, salt, tomatoes, g...
# 2      20130     filipino  [eggs, pepper, salt, mayonaise, cooking oil, g...
# 3      22213       indian                [water, vegetable oil, wheat, salt]
# 4      13162       indian  [black pepper, shallots, cornflour, cayenne pe...
# ...      ...          ...                                                ...
# 39769  29109        irish  [light brown sugar, granulated sugar, butter, ...
# 39770  11462      italian  [KRAFT Zesty Italian Dressing, purple onion, b...
# 39771   2238        irish  [eggs, citrus fruit, raisins, sourdough starte...
# 39772  41882      chinese  [boneless chicken skinless thigh, minced garli...
# 39773   2362      mexican  [green chile, jalapeno chilies, onions, ground...
#
# [39774 rows x 3 columns]

# %%
# loading dataset from the url
pd.read_json('https://api.exchangerate-api.com/v4/latest/INR')
# Out:
#                              provider  \
# INR  https://www.exchangerate-api.com
# AED  https://www.exchangerate-api.com
# AFN  https://www.exchangerate-api.com
# ALL  https://www.exchangerate-api.com
# AMD  https://www.exchangerate-api.com
# ..                                ...
# XPF  https://www.exchangerate-api.com
# YER  https://www.exchangerate-api.com
# ZAR  https://www.exchangerate-api.com
# ZMW  https://www.exchangerate-api.com
# ZWL  https://www.exchangerate-api.com
#
#                           WARNING_UPGRADE_TO_V6  \
# INR  https://www.exchangerate-api.com/docs/free
# AED  https://www.exchangerate-api.com/docs/free
# AFN  https://www.exchangerate-api.com/docs/free
# ALL  https://www.exchangerate-api.com/docs/free
# AMD  https://www.exchangerate-api.com/docs/free
# ..                                          ...
# XPF  https://www.exchangerate-api.com/docs/free
# YER  https://www.exchangerate-api.com/docs/free
# ZAR  https://www.exchangerate-api.com/docs/free
# ZMW  https://www.exchangerate-api.com/docs/free
# ZWL  https://www.exchangerate-api.com/docs/free
#
#                                       terms base       date  \
# INR  https://www.exchangerate-api.com/terms  INR 2025-08-04
# AED  https://www.exchangerate-api.com/terms  INR 2025-08-04
# AFN  https://www.exchangerate-api.com/terms  INR 2025-08-04
# ALL  https://www.exchangerate-api.com/terms  INR 2025-08-04
# AMD  https://www.exchangerate-api.com/terms  INR 2025-08-04
# ..                                      ...  ...        ...
# XPF  https://www.exchangerate-api.com/terms  INR 2025-08-04
# YER  https://www.exchangerate-api.com/terms  INR 2025-08-04
# ZAR  https://www.exchangerate-api.com/terms  INR 2025-08-04
# ZMW  https://www.exchangerate-api.com/terms  INR 2025-08-04
# ZWL  https://www.exchangerate-api.com/terms  INR 2025-08-04
#
#      time_last_updated  rates
# INR         1754265602  1.000
# AED         1754265602  0.042
# AFN         1754265602  0.787
# ALL         1754265602  0.972
# AMD         1754265602  4.390
# ..                 ...    ...
# XPF         1754265602  1.190
# YER         1754265602  2.750
# ZAR         1754265602  0.207
# ZMW         1754265602  0.263
# ZWL         1754265602  0.307
#
# [163 rows x 7 columns]

# %%
# working with SQL

# !pip install mysql.connector
# Out:
# Collecting mysql.connector
#   Downloading mysql-connector-2.2.9.tar.gz (11.9 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 11.9/11.9 MB 89.0 MB/s eta 0:00:00
#   Preparing metadata (setup.py) ... done
# Building wheels for collected packages: mysql.connector
#   Building wheel for mysql.connector (setup.py) ... done
#   Created wheel for mysql.connector: filename=mysql_connector-2.2.9-cp311-cp311-linux_x86_64.whl size=247951 sha256=1b1d30afb28fa70e428c9e53c91b1d6ee6dd38a885aca934512f5a1e4206cbbb
#   Stored in directory: /root/.cache/pip/wheels/17/cd/ed/2d49e9bac69cf09382e4c7cc20a2511202b48324b87db26019
# Successfully built mysql.connector
# Installing collected packages: mysql.connector
# Successfully installed mysql.connector-2.2.9

# %%
import mysql.connector

# %%
conn = mysql.connector.connect(host='localhost',use='root',password='',database='world')
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# /usr/local/lib/python3.11/dist-packages/mysql/connector/abstracts.py in config(self, **kwargs)
#     300             try:
# --> 301                 DEFAULT_CONFIGURATION[key]
#     302             except KeyError:
#
# KeyError: 'use'
#
# During handling of the above exception, another exception occurred:
#
# AttributeError                            Traceback (most recent call last)
# /tmp/ipython-input-762065600.py in <cell line: 0>()
# ----> 1 mysql.connector.connect(host='localhost',use='root',password='',database='world')
#
# /usr/local/lib/python3.11/dist-packages/mysql/connector/__init__.py in connect(*args, **kwargs)
#     177         return CMySQLConnection(*args, **kwargs)
#     178     else:
# --> 179         return MySQLConnection(*args, **kwargs)
#     180 Connect = connect  # pylint: disable=C0103
#     181
#
# /usr/local/lib/python3.11/dist-packages/mysql/connector/connection.py in __init__(self, *args, **kwargs)
#      93
#      94         if len(kwargs) > 0:
# ---> 95             self.connect(**kwargs)
#      96
#      97     def _do_handshake(self):
#
# /usr/local/lib/python3.11/dist-packages/mysql/connector/abstracts.py in connect(self, **kwargs)
#     711         """
#     712         if len(kwargs) > 0:
# --> 713             self.config(**kwargs)
#     714
#     715         self.disconnect()
#
# /usr/local/lib/python3.11/dist-packages/mysql/connector/abstracts.py in config(self, **kwargs)
#     301                 DEFAULT_CONFIGURATION[key]
#     302             except KeyError:
# --> 303                 raise AttributeError("Unsupported argument '{0}'".format(key))
#     304             # SSL Configuration
#     305             if key.startswith('ssl_'):
#
# AttributeError: Unsupported argument 'use'

# %%
pd.read_sql_query("SELECT * FROM city",conn)

# %%
pd.read_sql_query("SELECT * FROM city where CountryCode LIKE 'IND' ",conn)
