# %%
#  API : Application Programming Interface

# %%
# We are going to use TMDB's API

import pandas as pd
import requests

# %%
response = requests.get('https://api.themoviedb.org/3/movie/top_rated?api_key=b40df0b902b763d1296b53490620c78d&language=en-US&page=1')

# %%
# response 200 means ok

# %%
response.json()# explicitly converting incoming data into json
# Out:
# {'page': 1,
#  'results': [{'adult': False,
#    'backdrop_path': '/zfbjgQE1uSd9wiPTX4VzsLi0rGG.jpg',
#    'genre_ids': [18, 80],
#    'id': 278,
#    'original_language': 'en',
#    'original_title': 'The Shawshank Redemption',
#    'overview': 'Imprisoned in the 1940s for the double murder of his wife and her lover, upstanding banker Andy Dufresne begins a new life at the Shawshank prison, where he puts his accounting skills to work for an amoral warden. During his long stretch in prison, Dufresne comes to be admired by the other inmates -- including an older prisoner named Red -- for his integrity and unquenchable sense of hope.',
#    'popularity': 28.365,
#    'poster_path': '/9cqNxx0GxF0bflZmeSMuL5tnGzr.jpg',
#    'release_date': '1994-09-23',
#    'title': 'The Shawshank Redemption',
#    'video': False,
#    'vote_average': 8.712,
#    'vote_count': 28627},
#   {'adult': False,
#    'backdrop_path': '/htuuuEwAvDVECMpb0ltLLyZyDDt.jpg',
#    'genre_ids': [18, 80],
# ...

# %%
response.json()['results']
# Out:
# [{'adult': False,
#   'backdrop_path': '/zfbjgQE1uSd9wiPTX4VzsLi0rGG.jpg',
#   'genre_ids': [18, 80],
#   'id': 278,
#   'original_language': 'en',
#   'original_title': 'The Shawshank Redemption',
#   'overview': 'Imprisoned in the 1940s for the double murder of his wife and her lover, upstanding banker Andy Dufresne begins a new life at the Shawshank prison, where he puts his accounting skills to work for an amoral warden. During his long stretch in prison, Dufresne comes to be admired by the other inmates -- including an older prisoner named Red -- for his integrity and unquenchable sense of hope.',
#   'popularity': 28.365,
#   'poster_path': '/9cqNxx0GxF0bflZmeSMuL5tnGzr.jpg',
#   'release_date': '1994-09-23',
#   'title': 'The Shawshank Redemption',
#   'video': False,
#   'vote_average': 8.712,
#   'vote_count': 28627},
#  {'adult': False,
#   'backdrop_path': '/htuuuEwAvDVECMpb0ltLLyZyDDt.jpg',
#   'genre_ids': [18, 80],
#   'id': 238,
#   'original_language': 'en',
# ...

# %%
pd.DataFrame(response.json()['results'])# to converting data into pandas dataframe
pd.DataFrame(response.json()['results']).head(2)
# Out:
#    adult                     backdrop_path genre_ids   id original_language  \
# 0  False  /zfbjgQE1uSd9wiPTX4VzsLi0rGG.jpg  [18, 80]  278                en
# 1  False  /htuuuEwAvDVECMpb0ltLLyZyDDt.jpg  [18, 80]  238                en
#
#              original_title  \
# 0  The Shawshank Redemption
# 1             The Godfather
#
#                                             overview  popularity  \
# 0  Imprisoned in the 1940s for the double murder ...     28.3650
# 1  Spanning the years 1945 to 1955, a chronicle o...     28.1502
#
#                         poster_path release_date                     title  \
# 0  /9cqNxx0GxF0bflZmeSMuL5tnGzr.jpg   1994-09-23  The Shawshank Redemption
# 1  /3bhkrj58Vtu7enYsRolD1fZdja1.jpg   1972-03-14             The Godfather
#
#    video  vote_average  vote_count
# 0  False         8.712       28627
# 1  False         8.686       21672

# %%
df = pd.DataFrame(response.json()['results'])[['id','title','overview','release_date','popularity','vote_average','vote_count']]
#It will gives particular rows of that dataframe

# %%
df.head()
# Out:
#     id                     title  \
# 0  278  The Shawshank Redemption
# 1  238             The Godfather
# 2  240     The Godfather Part II
# 3  424          Schindler's List
# 4  389              12 Angry Men
#
#                                             overview release_date  popularity  \
# 0  Imprisoned in the 1940s for the double murder ...   1994-09-23     28.3650
# 1  Spanning the years 1945 to 1955, a chronicle o...   1972-03-14     28.1502
# 2  In the continuing saga of the Corleone crime f...   1974-12-20     18.1135
# 3  The true story of how businessman Oskar Schind...   1993-12-15     17.0177
# 4  The defense and the prosecution have rested an...   1957-04-10     16.2374
#
#    vote_average  vote_count
# 0         8.712       28627
# 1         8.686       21672
# 2         8.571       13085
# 3         8.566       16593
# 4         8.549        9291

# %%
df = pd.DataFrame()

# %%
df
# Out:
# Empty DataFrame
# Columns: []
# Index: []

# %%
for i in range (1,429):
  response = requests.get('https://api.themoviedb.org/3/movie/top_rated?api_key=b40df0b902b763d1296b53490620c78d&language=en-US&page={}'.format(i))
  temp_df = pd.DataFrame(response.json()['results'])[['id','title','overview','release_date','popularity','vote_average','vote_count']]
  # df = df.append(temp_df,ignore_index=True)
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# /tmp/ipython-input-2019121189.py in <cell line: 0>()
#       2   response = requests.get('https://api.themoviedb.org/3/movie/top_rated?api_key=b40df0b902b763d1296b53490620c78d&language=en-US&page={}'.format(i))
#       3   temp_df = pd.DataFrame(response.json()['results'])[['id','title','overview','release_date','popularity','vote_average','vote_count']]
# ----> 4   df = df.append(temp_df)
#
# /usr/local/lib/python3.11/dist-packages/pandas/core/generic.py in __getattr__(self, name)
#    6297         ):
#    6298             return self[name]
# -> 6299         return object.__getattribute__(self, name)
#    6300
#    6301     @final
#
# AttributeError: 'DataFrame' object has no attribute 'append'

# %%
df
# Out:
# Empty DataFrame
# Columns: []
# Index: []

# %%
df.to_csv('movies.csv')
